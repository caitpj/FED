# %%
from fed.plot_utils import load_gdp_long, plot_gdp_timeseries

CSV_NAME = "GDP_data_in_current_USD.csv"
COUNTRIES = ["United Kingdom", "United States", "Brazil", "Japan", "China", "Germany", "Switzerland"]

df_long = load_gdp_long(CSV_NAME)

# absolute values
ax = plot_gdp_timeseries(df_long, COUNTRIES, title="GDP over time", log_scale=True)

# or indexed to 100
ax = plot_gdp_timeseries(df_long, COUNTRIES, title="GDP indexed to first year = 100", normalize=True)
# Out:
# There are no nulls in the dataframe.
# /home/yasmin/miniconda3/envs/d100ps1/FED/fed/plot_utils.py:82: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for country, sub in data.groupby("Country Name", sort=False):
# /home/yasmin/miniconda3/envs/d100ps1/FED/fed/plot_utils.py:71: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   base = data.groupby("Country Name")["gdp"].transform("first")
# ...

# %%
import matplotlib
import pandas as pd
print("matplotlib:", matplotlib.__version__)
print("pandas:", pd.__version__)
# Out:
# matplotlib: 3.10.6
# pandas: 2.3.3
