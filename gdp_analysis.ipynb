# %%
from fed.plot_utils import load_gdp_long, plot_gdp_timeseries

csv_path = "fed/raw_data/GDP_data_in_current_USD.csv"
countries = ["United Kingdom", "United States", "Brazil", "Japan", "China", "Germany", "Switzerland"]

df_long = load_gdp_long(csv_path)

# absolute values
ax = plot_gdp_timeseries(df_long, countries, title="GDP over time", log_scale=True)

# or indexed to 100
ax = plot_gdp_timeseries(df_long, countries, title="GDP indexed to first year = 100", normalize=True)
# Out:
#      Country Name           2000           2001           2002           2003  \
# 0          Brazil   655448231984   559983634799   509795273807   558233745652
# 1     Switzerland   279216033870   286582672434   309301422430   362075086508
# 2           China  1223754919971  1355036590252  1489821682051  1683903309844
# 3         Germany  1966980701145  1966381496642  2102350798306  2534715518349
# 4  United Kingdom  1665534876683  1649827263567  1785729916067  2054422857143
#
#             2004           2005           2006           2007           2008  \
# 0   669289424806   891633839894  1107626541435  1397114486369  1695855083498
# 1   403912891033   418284865885   441634672197   490740715595   567267767519
# 2  1984196551300  2317551298052  2791498472804  3604055822572  4667346414522
# 3  2852317768062  2893393187362  3046308753671  3484056680855  3808786022313
# 4  2421525082387  2543180000000  2708441582337  3090510204082  2929411764706
#
#    ...           2013            2014            2015            2016  \
# 0  ...  2472819535557   2456043727199   1802212206815   1795693482853
# 1  ...   706234937371    726537809430    694118186380    687895460903
# 2  ...  9743124247267  10674533168257  11280814787469  11456024084962
# 3  ...  3808086291482   3965800686310   3423568450957   3537784107981
# 4  ...  2784853502534   3064708247921   2927911140917   2689106566900
#
#              2017            2018            2019            2020  \
# 0   2063514977366   1916933898011   1873288205060   1476107231310
# 1    695200834102    725568717468    721369112727    741999406006
# 2  12537559062283  14147765772964  14560167101283  14996414166715
# 3   3763092263753   4052008447224   3957208055216   3940142541354
# 4   2680148052335   2871340347582   2851407164908   2696778386608
#
#              2021            2022
# 0   1670647398905   1951923942083
# 1    815309330987    828508926958
# 2  18201698719564  18316765021690
# 3   4348297440388   4163596357879
# 4   3143323050707   3114042471144
#
# [5 rows x 24 columns]
#      Country Name  year            gdp
# 0          Brazil  2000   655448231984
# 1     Switzerland  2000   279216033870
# 2           China  2000  1223754919971
# 3         Germany  2000  1966980701145
# 4  United Kingdom  2000  1665534876683
# Country Name    False
# year            False
# gdp             False
# dtype: bool
# c:\Users\tilik\Cambridge\Year_1\D100\PS_1\FED\fed\plot_utils.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for country, sub in data.groupby("Country Name", sort=False):
# c:\Users\tilik\Cambridge\Year_1\D100\PS_1\FED\fed\plot_utils.py:67: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   base = data.groupby("Country Name")["gdp"].transform("first")
# c:\Users\tilik\Cambridge\Year_1\D100\PS_1\FED\fed\plot_utils.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for country, sub in data.groupby("Country Name", sort=False):

# %%
import matplotlib
import pandas as pd
print("matplotlib:", matplotlib.__version__)
print("pandas:", pd.__version__)
# Out:
# matplotlib: 3.10.7
# pandas: 2.3.3
